# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the data
file = "all_auto_and_manual_patterns.csv"
file1 = "../RQ1/GH_labelled_combined_csv_file.csv"
file2 = "../RQ1/HF_all_labels_from_gemini.csv"
f2 = "../RQ1/must_exclude_from_all_analysis.csv"

df1 = pd.read_csv(file, encoding='latin1')
df2 = pd.read_csv(f2, encoding='latin1')

# Exclude specific families
exclusion = list(df2['family'].unique())
dfs = df1[~df1['family'].isin(exclusion)]

# Replace 'Dispersed Alignment' with 'Disperse Alignment'
name_mapping = {
    'Dense Alignment Patter': 'Dense Synchronization',
    'Frequent Alignment Pattern': 'Frequent Synchronization',
    'Intermittent Alignment Pattern': 'Intermittent Synchronization',
    'Rare Alignment Pattern': 'Rare Synchronization',
    'Sparse Alignment Pattern': 'Sparse Synchronization',
    'Dispersed Alignment Pattern': 'Disperse Synchronization',
    'Dense Partial Alignment Pattern': 'Dense Partial Synchronization',
    'Sporadic Disjoint Pattern': 'Sporadic Disjoint Synchronization'
}
dfs['pattern_names'] = dfs['pattern_names'].replace(name_mapping)


GH1 = pd.read_csv(file1, encoding='latin1')
HF1 = pd.read_csv(file2, encoding='latin1')
dfs2 = pd.read_csv(f2, encoding='latin1')

exclusion = list(dfs2['family'].unique())
excluded_labels = ['bug fix', 'unclear', 'uncategorized', 'add model']

GH2 = GH1[~GH1['label'].isin(exclusion)]
HF2 = HF1[~HF1['label'].isin(exclusion)]

GH_main = GH2[~GH2['label'].isin(excluded_labels)]
HF_main = HF2[~HF2['label'].isin(excluded_labels)]

gf_dfs = dfs.groupby('family').agg({
    'pattern_names': lambda x: ''.join(x.unique())
}).reset_index()

GH = pd.merge(GH_main, gf_dfs, on='family', how='outer')
HF = pd.merge(HF_main, gf_dfs, on='family', how='outer')
HF
# Out:
# C:\Users\LabSystem\AppData\Local\Temp\ipykernel_2072\82645948.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfs['pattern_names'] = dfs['pattern_names'].replace(name_mapping)
# C:\Users\LabSystem\AppData\Local\Temp\ipykernel_2072\82645948.py:32: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   GH1 = pd.read_csv(file1, encoding='latin1')
#           owner               model_name created_at last_updated  \
# 0         01-ai    01-ai/Yi-1.5-34B-Chat  3/15/2024    7/29/2024
# 1         01-ai    01-ai/Yi-1.5-34B-Chat  3/15/2024    7/29/2024
# 2         01-ai    01-ai/Yi-1.5-34B-Chat  3/15/2024    7/29/2024
# 3         01-ai    01-ai/Yi-1.5-34B-Chat  3/15/2024    7/29/2024
# 4         01-ai    01-ai/Yi-1.5-34B-Chat  3/15/2024    7/29/2024
# ...         ...                      ...        ...          ...
# 17151  YituTech  YituTech/conv-bert-base   3/2/2022    2/24/2021
# 17152  YituTech  YituTech/conv-bert-base   3/2/2022    2/24/2021
# 17153  YituTech  YituTech/conv-bert-base   3/2/2022    2/24/2021
# 17154  YituTech  YituTech/conv-bert-base   3/2/2022    2/24/2021
# 17155  YituTech  YituTech/conv-bert-base   3/2/2022    2/24/2021
#
#                    family  model_size previous_size_category  downloads  \
# 0                01-ai_YI  6061.03552                  large      68355
# 1                01-ai_YI  6061.03552                  large      68355
# 2                01-ai_YI  6061.03552                  large      68355
# 3                01-ai_YI  6061.03552                  large      68355
# 4                01-ai_YI  6061.03552                  large      68355
# ...                   ...         ...                    ...        ...
# 17151  YituTech_conv-bert     0.00000                unknown    3038158
# 17152  YituTech_conv-bert     0.00000                unknown    3038158
# 17153  YituTech_conv-bert     0.00000                unknown    3038158
# 17154  YituTech_conv-bert     0.00000                unknown    3038158
# 17155  YituTech_conv-bert     0.00000                unknown    3038158
#
#        likes  library_name  ...                               cleaned_github  \
# 0        174  transformers  ...                  https://github.com/01-ai/yi
# 1        174  transformers  ...                  https://github.com/01-ai/yi
# 2        174  transformers  ...                  https://github.com/01-ai/yi
# 3        174  transformers  ...                  https://github.com/01-ai/yi
# 4        174  transformers  ...                  https://github.com/01-ai/yi
# ...      ...           ...  ...                                          ...
# 17151      8  transformers  ...  https://github.com/yitu-opensource/ConvBert
# 17152      8  transformers  ...  https://github.com/yitu-opensource/ConvBert
# 17153      8  transformers  ...  https://github.com/yitu-opensource/ConvBert
# 17154      8  transformers  ...  https://github.com/yitu-opensource/ConvBert
# 17155      8  transformers  ...  https://github.com/yitu-opensource/ConvBert
#
#                        title message  \
# 0      Upload tokenizer.json     NaN
# 1      Delete tokenizer.json     NaN
# 2              Upload NOTICE     NaN
# 3              Delete NOTICE     NaN
# 4              Upload NOTICE     NaN
# ...                      ...     ...
# 17151             fix config     NaN
# 17152          update models     NaN
# 17153               fix path     NaN
# 17154      add convbert base     NaN
# 17155         initial commit     NaN
#
#                                       commit_id       date     author  \
# 0      fa4ffba162f20948bf77c2a30eca952bf0812b7f  8/27/2024    Mia01ai
# 1      c778adea4d63eb5812ee2f4bfff0f43fe1e99cde  8/27/2024    Mia01ai
# 2      aa880dd36346295f0ef0255cd8c8e398251a0f5e  6/26/2024  Chen-01AI
# 3      8a09fd99c176e9024ee64e319883e4da479b8bc1  6/26/2024  Chen-01AI
# 4      3a2619d14e1cf6a9fe1792c2b96acfb4538272c7  6/26/2024  Chen-01AI
# ...                                         ...        ...        ...
# 17151  9001261c1cbfc93899a1cab9d2e9c980f65835a4   2/2/2021   abhishek
# 17152  3abdc6f9b0755d5260e97df36d4bfe147b0310b7  1/21/2021   abhishek
# 17153  64c19bcb08466f8547285d8d262ab8a723185309  1/21/2021   abhishek
# 17154  ea841915807b45fbaca73983bba97921046a5601  1/21/2021   abhishek
# 17155  64cda6d0ccc10d2e3d3d9b7bfa630b6f76cd329f  1/21/2021     system
#
#                                                    files  \
# 0                                         tokenizer.json
# 1                                         tokenizer.json
# 2                                                 NOTICE
# 3                                                 NOTICE
# 4                                                 NOTICE
# ...                                                  ...
# 17151                                        config.json
# 17152                     pytorch_model.bin, tf_model.h5
# 17153                                        config.json
# 17154  config.json, pytorch_model.bin, tf_model.h5, v...
# 17155                                     .gitattributes
#
#                     combined                   label             pattern_names
# 0      upload tokenizer.json           preprocessing  Frequent Synchronization
# 1      delete tokenizer.json           preprocessing  Frequent Synchronization
# 2              upload notice  external documentation  Frequent Synchronization
# 3              delete notice  external documentation  Frequent Synchronization
# 4              upload notice  external documentation  Frequent Synchronization
# ...                      ...                     ...                       ...
# 17151             fix config        parameter tuning     Rare Disjoing pattern
# 17152          update models         model structure     Rare Disjoing pattern
# 17153               fix path           preprocessing     Rare Disjoing pattern
# 17154      add convbert base         model structure     Rare Disjoing pattern
# 17155         initial commit        project metadata     Rare Disjoing pattern
#
# [17156 rows x 21 columns]

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the data
file = "all_auto_and_manual_patterns.csv"
file1 = "../RQ1/GH_labelled_combined_csv_file.csv"
file2 = "../RQ1/HF_all_labels_from_gemini.csv"
f2 = "../RQ1/must_exclude_from_all_analysis.csv"

df1 = pd.read_csv(file, encoding='latin1')
df2 = pd.read_csv(f2, encoding='latin1')

# Exclude specific families
exclusion = list(df2['family'].unique())
dfs = df1[~df1['family'].isin(exclusion)]

# Replace 'Dispersed Alignment' with 'Disperse Alignment'
name_mapping = {
    'Dense Alignment Patter': 'Dense Synchronization',
    'Frequent Alignment Pattern': 'Frequent Synchronization',
    'Intermittent Alignment Pattern': 'Intermittent Synchronization',
    'Rare Alignment Pattern': 'Rare Synchronization',
    'Sparse Alignment Pattern': 'Sparse Synchronization',
    'Dispersed Alignment Pattern': 'Disperse Synchronization',
    'Dense Partial Alignment Pattern': 'Dense Partial Synchronization',
    'Sporadic Disjoint Pattern': 'Sporadic Disjoint Synchronization'
}
dfs['pattern_names'] = dfs['pattern_names'].replace(name_mapping)


GH1 = pd.read_csv(file1, encoding='latin1')
HF1 = pd.read_csv(file2, encoding='latin1')
dfs2 = pd.read_csv(f2, encoding='latin1')

exclusion = list(dfs2['family'].unique())
excluded_labels = ['bug fix', 'unclear', 'uncategorized', 'add model']

GH2 = GH1[~GH1['label'].isin(exclusion)]
HF2 = HF1[~HF1['label'].isin(exclusion)]

GH_main = GH2[~GH2['label'].isin(excluded_labels)]
HF_main = HF2[~HF2['label'].isin(excluded_labels)]

gf_dfs = dfs.groupby('family').agg({
    'pattern_names': lambda x: ''.join(x.unique())
}).reset_index()

GH = pd.merge(GH_main, gf_dfs, on='family', how='outer')
HF = pd.merge(HF_main, gf_dfs, on='family', how='outer')

GH_prev = GH.groupby(['family', 'pattern_names', 'label']).agg({
    'commit_message': 'nunique',
    'author_username': 'nunique'
}).reset_index()


HF_prev = HF.groupby(['family', 'pattern_names', 'label']).agg({
    'combined': 'nunique',
    'author': 'nunique'
}).reset_index()

HF_prev
# Out:
# C:\Users\LabSystem\AppData\Local\Temp\ipykernel_2072\8594368.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfs['pattern_names'] = dfs['pattern_names'].replace(name_mapping)
# C:\Users\LabSystem\AppData\Local\Temp\ipykernel_2072\8594368.py:32: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   GH1 = pd.read_csv(file1, encoding='latin1')
#                    family             pattern_names                   label  \
# 0                01-ai_YI  Frequent Synchronization          add dependency
# 1                01-ai_YI  Frequent Synchronization  external documentation
# 2                01-ai_YI  Frequent Synchronization              input data
# 3                01-ai_YI  Frequent Synchronization         model structure
# 4                01-ai_YI  Frequent Synchronization             output data
# ...                   ...                       ...                     ...
# 1793          yahma_llama     Rare Disjoing pattern  external documentation
# 1794          yahma_llama     Rare Disjoing pattern        project metadata
# 1795  yangheng_absa-model  Disperse Synchronization  external documentation
# 1796  yangheng_absa-model  Disperse Synchronization             output data
# 1797  yangheng_absa-model  Disperse Synchronization        project metadata
#
#       combined  author
# 0            2       2
# 1           25      12
# 2            1       1
# 3            9       3
# 4            2       1
# ...        ...     ...
# 1793         1       1
# 1794         2       1
# 1795         1       1
# 1796         1       1
# 1797         2       2
#
# [1798 rows x 5 columns]

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# === Load the data ===
file = "all_auto_and_manual_patterns.csv"
file1 = "../RQ1/GH_labelled_combined_csv_file.csv"
file2 = "../RQ1/HF_all_labels_from_gemini.csv"
f2 = "../RQ1/must_exclude_from_all_analysis.csv"

df1 = pd.read_csv(file, encoding='latin1')
df2 = pd.read_csv(f2, encoding='latin1')

# === Exclude specific families ===
exclusion = list(df2['family'].unique())
dfs = df1[~df1['family'].isin(exclusion)]

# === Clean up pattern name mappings ===
name_mapping = {
    'Dense Alignment Patter': 'Dense Synchronization',
    'Frequent Alignment Pattern': 'Frequent Synchronization',
    'Intermittent Alignment Pattern': 'Intermittent Synchronization',
    'Rare Alignment Pattern': 'Rare Synchronization',
    'Sparse Alignment Pattern': 'Sparse Synchronization',
    'Dispersed Alignment Pattern': 'Disperse Synchronization',
    'Dense Partial Alignment Pattern': 'Dense Partial Synchronization',
    'Sporadic Disjoint Pattern': 'Sporadic Disjoint Synchronization'
}
dfs['pattern_names'] = dfs['pattern_names'].replace(name_mapping)

# === Keep only unique (family, pattern) mappings ===
gf_dfs = dfs[['family', 'pattern_names']].drop_duplicates()

# === Load GH label data ===
GH1 = pd.read_csv(file1, encoding='latin1')

# === Exclude unwanted families and labels ===
excluded_labels = ['bug fix', 'unclear', 'uncategorized', 'add model']
GH2 = GH1[~GH1['label'].isin(exclusion)]
GH_main = GH2[~GH2['label'].isin(excluded_labels)]

# === Merge GitHub data with pattern information ===
GH = pd.merge(GH_main, gf_dfs, on='family', how='inner')

# === Count commits per (pattern, label) ===
GH_prev = GH.groupby(['pattern_names', 'label']).agg({
    'commit_message': 'nunique',
}).reset_index().rename(columns={'commit_message': 'count'})

# === Pivot for heatmap ===
pivot_gh = GH_prev.pivot_table(index='pattern_names', columns='label', values='count', fill_value=0)

# === Normalize rows to get proportions ===
pivot_gh_prop = pivot_gh.div(pivot_gh.sum(axis=1), axis=0)


pivot_gh_prop = pivot_gh_prop.sort_index(axis=0).sort_index(axis=1)

# Adjust figure size dynamically based on number of columns/labels
num_patterns = pivot_gh_prop.shape[0]
num_labels = pivot_gh_prop.shape[1]

# Use larger figure for readability
fig_width = max(12, num_labels * 0.8)
fig_height = max(6, num_patterns * 0.6)

plt.figure(figsize=(fig_width, fig_height))
sns.heatmap(
    pivot_gh_prop,
    annot=True,
    fmt=".2f",
    cmap="YlGnBu",
    linewidths=0.1,
    linecolor='gray',
    cbar_kws={'label': 'Proportion'},
    annot_kws={"size": 12}
)

plt.title("GitHub: Proportion of Change Types by Synchronization Pattern", fontsize=14)
plt.ylabel("Synchronization Pattern", fontsize=14)
plt.xlabel("Change Type", fontsize=14)

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha='right', fontsize=14)
plt.yticks(fontsize=14)

plt.tight_layout()
plt.show()
# Out:
# C:\Users\LabSystem\AppData\Local\Temp\ipykernel_2072\3875004689.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfs['pattern_names'] = dfs['pattern_names'].replace(name_mapping)
# C:\Users\LabSystem\AppData\Local\Temp\ipykernel_2072\3875004689.py:35: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   GH1 = pd.read_csv(file1, encoding='latin1')

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# === Load and clean ===
file = "all_auto_and_manual_patterns.csv"
file2 = "../RQ1/HF_all_labels_from_gemini.csv"
f2 = "../RQ1/must_exclude_from_all_analysis.csv"

df_patterns = pd.read_csv(file, encoding='latin1')
df_exclude = pd.read_csv(f2, encoding='latin1')
HF_raw = pd.read_csv(file2, encoding='latin1')

# === Map patterns ===
exclusion = list(df_exclude['family'].unique())
df_patterns = df_patterns[~df_patterns['family'].isin(exclusion)]

# Normalize pattern names
name_mapping = {
    'Dense Alignment Patter': 'Dense Synchronization',
    'Frequent Alignment Pattern': 'Frequent Synchronization',
    'Intermittent Alignment Pattern': 'Intermittent Synchronization',
    'Rare Alignment Pattern': 'Rare Synchronization',
    'Sparse Alignment Pattern': 'Sparse Synchronization',
    'Dispersed Alignment Pattern': 'Disperse Synchronization',
    'Dense Partial Alignment Pattern': 'Dense Partial Synchronization',
    'Sporadic Disjoint Pattern': 'Sporadic Disjoint Synchronization'
}
df_patterns['pattern_names'] = df_patterns['pattern_names'].replace(name_mapping)
pattern_map = df_patterns[['family', 'pattern_names']].drop_duplicates()

# === Preprocess HF data ===
excluded_labels = ['bug fix', 'unclear', 'uncategorized', 'add model']
HF_filtered = HF_raw[~HF_raw['label'].isin(excluded_labels)]
HF_filtered = HF_filtered[~HF_filtered['family'].isin(exclusion)]

# Merge with pattern names
HF = pd.merge(HF_filtered, pattern_map, on='family', how='inner')

# === Step 1: calculate per-repo (i.e., model_id) label distribution ===
repo_label_counts = HF.groupby(['model_name', 'label']).size().reset_index(name='count')

# Normalize per model (row-wise)
repo_totals = repo_label_counts.groupby('model_name')['count'].transform('sum')
repo_label_counts['proportion'] = repo_label_counts['count'] / repo_totals

# Add pattern and family back in
repo_metadata = HF[['model_name', 'family', 'pattern_names']].drop_duplicates()
repo_label_counts = pd.merge(repo_label_counts, repo_metadata, on='model_name', how='left')

# === Step 2: for each pattern and label, compute the median proportion ===
pattern_label_medians = repo_label_counts.groupby(['pattern_names', 'label'])['proportion'].median().reset_index()

# Pivot for heatmap
pivot_median = pattern_label_medians.pivot(index='pattern_names', columns='label', values='proportion').fillna(0)

log_pivot = np.log10(pivot_median + 1e-4)

# === Plot ===
num_patterns = log_pivot.shape[0]
num_labels = log_pivot.shape[1]

fig_width = max(12, num_labels * 0.8)
fig_height = max(6, num_patterns * 0.6)

plt.figure(figsize=(fig_width, fig_height))
sns.heatmap(
    log_pivot,
    annot=pivot_median,  # show original proportions
    fmt=".2f",
    cmap="YlGnBu",
    linewidths=0.1,
    linecolor='gray',
    cbar_kws={'label': 'log10(Proportion + 1e-4)'},
    annot_kws={"size": 12}
)

plt.title("Hugging Face: Median Proportion of Change Types by Synchronization Pattern (Log Scale)", fontsize=14)
plt.ylabel("Synchronization Pattern", fontsize=14)
plt.xlabel("Change Type", fontsize=14)
plt.xticks(rotation=45, ha='right', fontsize=14)
plt.yticks(fontsize=14)

plt.tight_layout()
plt.show()

# %%
import pandas as pd

# === Load preprocessed GitHub and Hugging Face proportion data ===
# Assumes these are the already-normalized (row-wise) pivot tables you computed earlier:
# pivot_gh_prop and pivot_hf_median (i.e., the median HF proportions per pattern/label)

# Rename Hugging Face table for clarity
pivot_hf_prop = pivot_median.copy()  # make sure this is your HF median proportion pivot
pivot_hf_prop.name = 'Hugging Face'

# GitHub table (proportion of commits per pattern)
pivot_gh_prop.name = 'GitHub'

# === Melt both tables ===
gh_melted = pivot_gh_prop.reset_index().melt(id_vars='pattern_names', var_name='label', value_name='gh_prop')
hf_melted = pivot_hf_prop.reset_index().melt(id_vars='pattern_names', var_name='label', value_name='hf_prop')

# === Merge both ===
merged = pd.merge(gh_melted, hf_melted, on=['pattern_names', 'label'], how='outer').fillna(0)

# === Compute absolute difference and dominant platform ===
merged['abs_diff'] = (merged['gh_prop'] - merged['hf_prop']).abs()
merged['dominant_platform'] = merged.apply(
    lambda row: 'GitHub' if row['gh_prop'] > row['hf_prop'] else ('Hugging Face' if row['hf_prop'] > row['gh_prop'] else 'Equal'),
    axis=1
)

# === Sort for readability ===
merged = merged.sort_values(by=['pattern_names', 'abs_diff'], ascending=[True, False])

# === Optional: Save result to CSV ===
merged.to_csv("change_type_dominance_by_pattern.csv", index=False)

# === Preview top rows ===
merged.head(20)
# Out:
#                      pattern_names                      label   gh_prop  \
# 8    Dense Partial Synchronization     external documentation  0.100671
# 32   Dense Partial Synchronization            model structure  0.450275
# 64   Dense Partial Synchronization              preprocessing  0.049420
# 96   Dense Partial Synchronization    training infrastructure  0.144600
# 40   Dense Partial Synchronization                output data  0.001830
# 48   Dense Partial Synchronization           parameter tuning  0.032337
# 16   Dense Partial Synchronization                 input data  0.014033
# 72   Dense Partial Synchronization           project metadata  0.014948
# 24   Dense Partial Synchronization     internal documentation  0.032642
# 56   Dense Partial Synchronization       pipeline performance  0.023795
# 80   Dense Partial Synchronization          remove dependency  0.003051
# 112  Dense Partial Synchronization  validation infrastructure  0.040879
# 0    Dense Partial Synchronization             add dependency  0.029286
# 104  Dense Partial Synchronization          update dependency  0.014948
# 88   Dense Partial Synchronization                    sharing  0.047285
# 9         Disperse Synchronization     external documentation  0.177705
# 49        Disperse Synchronization           parameter tuning  0.029635
# 65        Disperse Synchronization              preprocessing  0.059798
# 41        Disperse Synchronization                output data  0.006222
# 33        Disperse Synchronization            model structure  0.267349
#
#       hf_prop  abs_diff dominant_platform
# 8    0.384615  0.283944      Hugging Face
# 32   0.200000  0.250275            GitHub
# 64   0.166667  0.117246      Hugging Face
# 96   0.030303  0.114297            GitHub
# 40   0.074026  0.072196      Hugging Face
# 48   0.100000  0.067663      Hugging Face
# 16   0.076149  0.062116      Hugging Face
# 72   0.066667  0.051719      Hugging Face
# 24   0.076923  0.044281      Hugging Face
# 56   0.061111  0.037316      Hugging Face
# 80   0.029437  0.026386      Hugging Face
# 112  0.048780  0.007902      Hugging Face
# 0    0.021739  0.007547            GitHub
# 104  0.021739  0.006791      Hugging Face
# 88   0.050575  0.003290      Hugging Face
# 9    0.333333  0.155628      Hugging Face
# 49   0.160000  0.130365      Hugging Face
# 65   0.166667  0.106869      Hugging Face
# 41   0.111111  0.104889      Hugging Face
# 33   0.166667  0.100682            GitHub

# %%
import pandas as pd
from scipy.stats import chi2_contingency

GH_prev = GH.groupby(['pattern_names', 'label']).agg({
    'commit_message': 'nunique',
}).reset_index().rename(columns={'commit_message': 'count'})

pivot_gh = GH_prev.pivot_table(index='pattern_names', columns='label', values='count', fill_value=0)

pattern_label_medians = repo_label_counts.groupby(['pattern_names', 'label'])['proportion'].median().reset_index()
pivot_median = pattern_label_medians.pivot(index='pattern_names', columns='label', values='proportion').fillna(0)

HF_counts = HF.groupby(['pattern_names', 'label']).agg({
    'combined': 'nunique'  # or 'count' if 'commit_message' unavailable
}).reset_index().rename(columns={'combined': 'count'})

pivot_hf = HF_counts.pivot_table(index='pattern_names', columns='label', values='count', fill_value=0)

def chi_square_test_change_type(pivot_gh, pivot_hf):
    change_types = set(pivot_gh.columns).intersection(pivot_hf.columns)
    patterns = set(pivot_gh.index).union(pivot_hf.index)
    
    results = []
    
    for change in change_types:
        gh_counts = pivot_gh[change].reindex(patterns, fill_value=0)
        hf_counts = pivot_hf[change].reindex(patterns, fill_value=0)
        
        contingency = pd.DataFrame({
            'GitHub': gh_counts,
            'HuggingFace': hf_counts
        }).T
        
        chi2, p, dof, expected = chi2_contingency(contingency)
        
        results.append({
            'change_type': change,
            'chi2_statistic': chi2,
            'p_value': p,
            'degrees_of_freedom': dof,
            'significant_at_0.05': p < 0.05
        })
    
    return pd.DataFrame(results).sort_values('p_value')

# Run test
results_df = chi_square_test_change_type(pivot_gh, pivot_hf)
results_df
# Out:
#                   change_type  chi2_statistic        p_value  \
# 9             model structure     1820.054897   0.000000e+00
# 6      external documentation      952.950821  1.758585e-201
# 1               preprocessing      762.355328  2.458876e-160
# 5            parameter tuning      300.261282   5.320248e-61
# 0                 output data      208.600794   1.727768e-41
# 7     training infrastructure      182.827210   4.925326e-36
# 10  validation infrastructure      168.289428   5.758982e-33
# 11                    sharing      156.378949   1.853384e-30
# 14           project metadata      149.928011   4.203696e-29
# 2      internal documentation      102.751352   2.913224e-19
# 3        pipeline performance       66.904673   6.222964e-12
# 12                 input data       61.342423   8.138925e-11
# 8              add dependency       60.425036   1.241537e-10
# 13          update dependency       39.949301   1.287229e-06
# 4           remove dependency       25.028224   7.501074e-04
#
#     degrees_of_freedom  significant_at_0.05
# 9                    7                 True
# 6                    7                 True
# 1                    7                 True
# 5                    7                 True
# 0                    7                 True
# 7                    7                 True
# 10                   7                 True
# 11                   7                 True
# 14                   7                 True
# 2                    7                 True
# 3                    7                 True
# 12                   7                 True
# 8                    7                 True
# 13                   7                 True
# 4                    7                 True

# %%
pivot_hf
# Out:
# label                              add dependency  external documentation  \
# pattern_names
# Dense Partial Synchronization                 1.0                    72.0
# Disperse Synchronization                     22.0                   553.0
# Frequent Synchronization                      3.0                   117.0
# Intermittent Synchronization                  3.0                    99.0
# Rare Disjoing pattern                         2.0                    24.0
# Rare Synchronization                          4.0                    69.0
# Sparse Synchronization                        2.0                    80.0
# Sporadic Disjoint Synchronization             4.0                   129.0
#
# label                              input data  internal documentation  \
# pattern_names
# Dense Partial Synchronization             5.0                     2.0
# Disperse Synchronization                 26.0                    15.0
# Frequent Synchronization                  1.0                     1.0
# Intermittent Synchronization              4.0                     2.0
# Rare Disjoing pattern                     0.0                     1.0
# Rare Synchronization                      0.0                     2.0
# Sparse Synchronization                    3.0                     5.0
# Sporadic Disjoint Synchronization         2.0                     7.0
#
# label                              model structure  output data  \
# pattern_names
# Dense Partial Synchronization                 60.0         10.0
# Disperse Synchronization                     530.0        298.0
# Frequent Synchronization                      56.0         24.0
# Intermittent Synchronization                 104.0         21.0
# Rare Disjoing pattern                         32.0          5.0
# Rare Synchronization                          39.0          9.0
# Sparse Synchronization                        64.0          6.0
# Sporadic Disjoint Synchronization             90.0         29.0
#
# label                              parameter tuning  pipeline performance  \
# pattern_names
# Dense Partial Synchronization                  21.0                   3.0
# Disperse Synchronization                       96.0                  13.0
# Frequent Synchronization                       12.0                   2.0
# Intermittent Synchronization                   17.0                   0.0
# Rare Disjoing pattern                           4.0                   0.0
# Rare Synchronization                           10.0                   1.0
# Sparse Synchronization                         12.0                   1.0
# Sporadic Disjoint Synchronization              23.0                   1.0
#
# label                              preprocessing  project metadata  \
# pattern_names
# Dense Partial Synchronization               50.0              17.0
# Disperse Synchronization                   269.0              81.0
# Frequent Synchronization                    38.0              15.0
# Intermittent Synchronization                42.0               6.0
# Rare Disjoing pattern                       18.0              11.0
# Rare Synchronization                        26.0              19.0
# Sparse Synchronization                      33.0              17.0
# Sporadic Disjoint Synchronization           97.0              21.0
#
# label                              remove dependency  sharing  \
# pattern_names
# Dense Partial Synchronization                    2.0      9.0
# Disperse Synchronization                        20.0     65.0
# Frequent Synchronization                         3.0    100.0
# Intermittent Synchronization                    12.0     17.0
# Rare Disjoing pattern                            2.0      3.0
# Rare Synchronization                             9.0     28.0
# Sparse Synchronization                           5.0     22.0
# Sporadic Disjoint Synchronization                0.0      8.0
#
# label                              training infrastructure  update dependency  \
# pattern_names
# Dense Partial Synchronization                          3.0                1.0
# Disperse Synchronization                              45.0               10.0
# Frequent Synchronization                               3.0                1.0
# Intermittent Synchronization                           6.0                1.0
# Rare Disjoing pattern                                  2.0                1.0
# Rare Synchronization                                   7.0                0.0
# Sparse Synchronization                                21.0                2.0
# Sporadic Disjoint Synchronization                      7.0                0.0
#
# label                              validation infrastructure
# pattern_names
# Dense Partial Synchronization                            7.0
# Disperse Synchronization                                72.0
# Frequent Synchronization                                12.0
# Intermittent Synchronization                            19.0
# Rare Disjoing pattern                                    3.0
# Rare Synchronization                                     5.0
# Sparse Synchronization                                   5.0
# Sporadic Disjoint Synchronization                       14.0

# %%
pivot_gh
# Out:
# label                              add dependency  external documentation  \
# pattern_names
# Dense Partial Synchronization                96.0                   330.0
# Disperse Synchronization                    495.0                  3370.0
# Frequent Synchronization                    290.0                  1619.0
# Intermittent Synchronization               1247.0                  7385.0
# Rare Disjoing pattern                        21.0                   265.0
# Rare Synchronization                        377.0                  1920.0
# Sparse Synchronization                      179.0                  1093.0
# Sporadic Disjoint Synchronization            61.0                   671.0
#
# label                              input data  internal documentation  \
# pattern_names
# Dense Partial Synchronization            46.0                   107.0
# Disperse Synchronization                862.0                   902.0
# Frequent Synchronization                374.0                   641.0
# Intermittent Synchronization           1210.0                  1879.0
# Rare Disjoing pattern                    54.0                    25.0
# Rare Synchronization                    205.0                   287.0
# Sparse Synchronization                  160.0                   279.0
# Sporadic Disjoint Synchronization        73.0                    62.0
#
# label                              model structure  output data  \
# pattern_names
# Dense Partial Synchronization               1476.0          6.0
# Disperse Synchronization                    5070.0        118.0
# Frequent Synchronization                    4006.0         67.0
# Intermittent Synchronization               18233.0        130.0
# Rare Disjoing pattern                        138.0          2.0
# Rare Synchronization                        2614.0         37.0
# Sparse Synchronization                      1184.0         26.0
# Sporadic Disjoint Synchronization            467.0         28.0
#
# label                              parameter tuning  pipeline performance  \
# pattern_names
# Dense Partial Synchronization                 106.0                  78.0
# Disperse Synchronization                      562.0                 507.0
# Frequent Synchronization                      496.0                 279.0
# Intermittent Synchronization                 1733.0                2281.0
# Rare Disjoing pattern                          27.0                  15.0
# Rare Synchronization                          391.0                 381.0
# Sparse Synchronization                        102.0                 170.0
# Sporadic Disjoint Synchronization              75.0                  33.0
#
# label                              preprocessing  project metadata  \
# pattern_names
# Dense Partial Synchronization              162.0              49.0
# Disperse Synchronization                  1134.0             762.0
# Frequent Synchronization                  1186.0             296.0
# Intermittent Synchronization              2448.0             909.0
# Rare Disjoing pattern                       58.0              47.0
# Rare Synchronization                       545.0             418.0
# Sparse Synchronization                     338.0             213.0
# Sporadic Disjoint Synchronization          161.0             109.0
#
# label                              remove dependency  sharing  \
# pattern_names
# Dense Partial Synchronization                   10.0    155.0
# Disperse Synchronization                       165.0    849.0
# Frequent Synchronization                       130.0    705.0
# Intermittent Synchronization                   366.0   1807.0
# Rare Disjoing pattern                           14.0     27.0
# Rare Synchronization                            72.0    370.0
# Sparse Synchronization                          48.0    316.0
# Sporadic Disjoint Synchronization               11.0    100.0
#
# label                              training infrastructure  update dependency  \
# pattern_names
# Dense Partial Synchronization                        474.0               49.0
# Disperse Synchronization                            1931.0              534.0
# Frequent Synchronization                            1018.0              343.0
# Intermittent Synchronization                        5175.0             1408.0
# Rare Disjoing pattern                                 54.0               14.0
# Rare Synchronization                                 917.0              357.0
# Sparse Synchronization                               385.0              121.0
# Sporadic Disjoint Synchronization                    183.0               66.0
#
# label                              validation infrastructure
# pattern_names
# Dense Partial Synchronization                          134.0
# Disperse Synchronization                              1703.0
# Frequent Synchronization                              1001.0
# Intermittent Synchronization                          4404.0
# Rare Disjoing pattern                                   39.0
# Rare Synchronization                                   720.0
# Sparse Synchronization                                 518.0
# Sporadic Disjoint Synchronization                      206.0

# %%
import pandas as pd
from scipy.stats import chi2_contingency

GH_prev = GH.groupby(['pattern_names', 'label']).agg({
    'commit_message': 'nunique',
}).reset_index().rename(columns={'commit_message': 'count'})

pivot_gh = GH_prev.pivot_table(index='pattern_names', columns='label', values='count', fill_value=0)

pattern_label_medians = repo_label_counts.groupby(['pattern_names', 'label'])['proportion'].median().reset_index()
pivot_median = pattern_label_medians.pivot(index='pattern_names', columns='label', values='proportion').fillna(0)

HF_counts = HF.groupby(['pattern_names', 'label']).agg({
    'combined': 'nunique'  # or 'count' if 'commit_message' unavailable
}).reset_index().rename(columns={'combined': 'count'})

pivot_hf = HF_counts.pivot_table(index='pattern_names', columns='label', values='count', fill_value=0)

def chi_square_by_pattern(pivot_gh, pivot_hf):
    common_patterns = sorted(set(pivot_gh.index).intersection(set(pivot_hf.index)))
    common_labels = sorted(set(pivot_gh.columns).intersection(set(pivot_hf.columns)))

    results = []

    for pattern in common_patterns:
        gh_row = pivot_gh.loc[pattern, common_labels].fillna(0)
        hf_row = pivot_hf.loc[pattern, common_labels].fillna(0)

        # Construct contingency table
        contingency = pd.DataFrame([gh_row, hf_row], index=['GitHub', 'Hugging Face'])
        #print(contingency)

        chi2, p, dof, _ = chi2_contingency(contingency)

        results.append({
            'pattern': pattern,
            'chi2_statistic': chi2,
            'p_value': p,
            'degrees_of_freedom': dof,
            'significant_at_0.05': p < 0.05
        })

    return pd.DataFrame(results).sort_values('p_value')

# Run it
pattern_results_df = chi_square_by_pattern(pivot_gh, pivot_hf)
pattern_results_df
# Out:
#                              pattern  chi2_statistic        p_value  \
# 1           Disperse Synchronization     2391.940441   0.000000e+00
# 2           Frequent Synchronization      619.006105  4.782589e-123
# 3       Intermittent Synchronization      572.732155  3.358559e-113
# 0      Dense Partial Synchronization      341.221429   2.850143e-64
# 7  Sporadic Disjoint Synchronization      225.584607   3.124530e-40
# 5               Rare Synchronization      212.914434   1.249906e-37
# 6             Sparse Synchronization       87.681631   1.038289e-12
# 4              Rare Disjoing pattern       64.148566   2.169528e-08
#
#    degrees_of_freedom  significant_at_0.05
# 1                  14                 True
# 2                  14                 True
# 3                  14                 True
# 0                  14                 True
# 7                  14                 True
# 5                  14                 True
# 6                  14                 True
# 4                  14                 True

# %%
common_patterns = sorted(set(pivot_gh.index).intersection(set(pivot_hf.index)))
common_labels = sorted(set(pivot_gh.columns).intersection(set(pivot_hf.columns)))

dominant_changes = []

for pattern in common_patterns:
    gh_row = pivot_gh.loc[pattern, common_labels].fillna(0)
    hf_row = pivot_hf.loc[pattern, common_labels].fillna(0)

    for label in common_labels:
        gh_val = gh_row[label]
        hf_val = hf_row[label]

        abs_diff = abs(gh_val - hf_val)
        dominant = 'GitHub' if gh_val > hf_val else ('Hugging Face' if hf_val > gh_val else 'Equal')

        dominant_changes.append({
            'pattern': pattern,
            'change_type': label,
            'GitHub_count': gh_val,
            'HF_count': hf_val,
            'abs_diff': abs_diff,
            'dominant_platform': dominant
        })

# Convert to DataFrame
dominance_df = pd.DataFrame(dominant_changes)

# Optionally: get top 3 contributors per pattern
top_dominant_per_pattern = (
    dominance_df.sort_values(['pattern', 'abs_diff'], ascending=[True, False])
    .groupby('pattern')
    .head(3)
)

#top_dominant_per_pattern.to_csv("dominant_change_types_by_pattern.csv", index=False)
top_dominant_per_pattern
# Out:
#                                pattern                change_type  \
# 4        Dense Partial Synchronization            model structure
# 12       Dense Partial Synchronization    training infrastructure
# 1        Dense Partial Synchronization     external documentation
# 19            Disperse Synchronization            model structure
# 16            Disperse Synchronization     external documentation
# 27            Disperse Synchronization    training infrastructure
# 34            Frequent Synchronization            model structure
# 31            Frequent Synchronization     external documentation
# 38            Frequent Synchronization              preprocessing
# 49        Intermittent Synchronization            model structure
# 46        Intermittent Synchronization     external documentation
# 57        Intermittent Synchronization    training infrastructure
# 61               Rare Disjoing pattern     external documentation
# 64               Rare Disjoing pattern            model structure
# 62               Rare Disjoing pattern                 input data
# 79                Rare Synchronization            model structure
# 76                Rare Synchronization     external documentation
# 87                Rare Synchronization    training infrastructure
# 94              Sparse Synchronization            model structure
# 91              Sparse Synchronization     external documentation
# 104             Sparse Synchronization  validation infrastructure
# 106  Sporadic Disjoint Synchronization     external documentation
# 109  Sporadic Disjoint Synchronization            model structure
# 119  Sporadic Disjoint Synchronization  validation infrastructure
#
#      GitHub_count  HF_count  abs_diff dominant_platform
# 4          1476.0      60.0    1416.0            GitHub
# 12          474.0       3.0     471.0            GitHub
# 1           330.0      72.0     258.0            GitHub
# 19         5070.0     530.0    4540.0            GitHub
# 16         3370.0     553.0    2817.0            GitHub
# 27         1931.0      45.0    1886.0            GitHub
# 34         4006.0      56.0    3950.0            GitHub
# 31         1619.0     117.0    1502.0            GitHub
# 38         1186.0      38.0    1148.0            GitHub
# 49        18233.0     104.0   18129.0            GitHub
# 46         7385.0      99.0    7286.0            GitHub
# 57         5175.0       6.0    5169.0            GitHub
# 61          265.0      24.0     241.0            GitHub
# 64          138.0      32.0     106.0            GitHub
# 62           54.0       0.0      54.0            GitHub
# 79         2614.0      39.0    2575.0            GitHub
# 76         1920.0      69.0    1851.0            GitHub
# 87          917.0       7.0     910.0            GitHub
# 94         1184.0      64.0    1120.0            GitHub
# 91         1093.0      80.0    1013.0            GitHub
# 104         518.0       5.0     513.0            GitHub
# 106         671.0     129.0     542.0            GitHub
# 109         467.0      90.0     377.0            GitHub
# 119         206.0      14.0     192.0            GitHub
